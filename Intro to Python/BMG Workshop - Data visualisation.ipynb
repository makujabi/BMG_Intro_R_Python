# %% [markdown]
# <a href="https://colab.research.google.com/github/makujabi/BMG_Intro_R_Python/blob/main/Intro%20to%20Python/BMG%20Workshop%20-%20Data%20visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Python Workshop
#
# **Dr Paul J van Staden & Dr Rene Stander**
#
# **30 September 2024**
#
# ![UPLogoLandscape.png](data:image/png;base64,...)

# %% [markdown]
# # Data visualisation
#
# In this section we will cover the following:
#
# *   Visualisation for categorical variables:
#  -   Barplots
# *   Visualisation for numerical variables:
#  -   Boxplots
#  -   Histograms
# *   Visualisation for paired variables:
#  -   Scatterplots
#
# The data used for this section are:
#
# 1.   Data on animals compiled from the South African Super Animals Trump cards.
#
# ![SASA_TrumpCards_Savanna_1st2Cards.png](data:image/png;base64,...)
#
# 2.   Data on the level of anxiety experienced by arachnophobes when interacing with spiders (adapted from Field (2009))
#
# *Data sources:*
#
#     South African National Parks and Pick n Pay (2017). South African Super Animals Trump Cards.
#     Field, A. (2009). Discovering Statistics using SPSS (and sex and drugs and rock ’n’ roll), SAGE Publications Ltd, London, UK.

# %% [markdown]
# ## Example: South African birds
#
# Consider the following variables for 108 animals:
#
# *   Card number
# *   Type of animal
# *   Habitat
# *   Species
# *   Age in years
# *   Weight in kilograms
# *   Size in centimeters
# *   Speed in kilometer per hour
# *   Vulnerability status scaled from 1 (highest risk) to 4 (lowest risk)
#
# The focus will be on the 36 birds in the data set.

# %% [markdown]
# Import the necessary packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Import the data set.

# %%
animals = pd.read_csv("SuperAnimals.csv")
animals
# Out:
#      Number                Animal  Habitat     Species   Age  Weight   Size  \
# 0         1  White headed vulture  Savanna        Bird  20.0     4.7   85.0
# 1         2         Secretarybird  Savanna        Bird  12.0     4.0  152.0
# 2         3                  Kudu  Savanna      Mammal  15.0   227.0  240.0
# 3         4       Blue wildebeest  Savanna      Mammal  20.0   250.0  240.0
# 4         5               Giraffe  Savanna      Mammal  25.0   828.0  505.0
# ..      ...                   ...      ...         ...   ...     ...    ...
# 103     104      Atlantic herring    Ocean        Fish  20.0     1.0   39.0
# 104     105              Cusk eel    Ocean        Fish  30.0    25.0  200.0
# 105     106       Oyster toadfish    Ocean        Fish   8.0     0.6   38.0
# 106     107     Cape rock lobster    Ocean  Crustacean  50.0     5.0   46.0
# 107     108    Bottlenose dolphin    Ocean      Mammal  35.0   300.0  400.0
#
#      Speed  Vulnerability
# 0     48.0              1
# ...

# %% [markdown]
# Subset the data to only consider the birds.

# %%
birds = animals.loc[animals["Species"] == "Bird", :]
birds
# Out:
#     Number                      Animal          Habitat Species   Age  \
# 0        1        White headed vulture          Savanna    Bird  20.0
# 1        2               Secretarybird          Savanna    Bird  12.0
# 9       10       Lilac breasted roller          Savanna    Bird  15.0
# 13      14              African jacana          Wetland    Bird   6.5
# 14      15            Greater flamingo          Wetland    Bird  30.0
# 15      16                  Blue crane          Wetland    Bird  30.0
# 17      18            Giant kingfisher          Wetland    Bird  10.0
# 19      20          Southern bald ibis          Wetland    Bird  15.0
# 20      21          African fish eagle          Wetland    Bird  24.0
# 22      23     Brown hooded kingfisher          Wetland    Bird  20.0
# 23      24          Yellow-billed duck          Wetland    Bird  30.0
# 24      25              Crested barbet          Thicket    Bird  10.0
# ...

# %% [markdown]
# Draw a barplot showing the number of birds in the different habitats.

# %%
birds_habitat = birds["Habitat"].value_counts()
sns.barplot(x = birds_habitat.index, y = birds_habitat.values)
# Out:
# <Axes: xlabel='Habitat'>

# %%
birds_habitat
# Out:
# Habitat
# Wetland            8
# Thicket            8
# Coast              6
# Fynbos             5
# Forest             3
# Savanna            3
# Nama Karoo         2
# Succulent Karoo    1
# Name: count, dtype: int64

# %% [markdown]
# Draw a barplot showing the vulnerability status of the birds.

# %%
birds_vulnerability = birds["Vulnerability"].value_counts()
sns.barplot(x = birds_vulnerability.index, y = birds_vulnerability.values)
# Out:
# <Axes: xlabel='Vulnerability'>

# %%
birds_vulnerability

# %% [markdown]
# Draw a boxplot for the age in years of the birds.

# %%
box_Age = sns.boxplot(data = birds,
                      x = "Age",
                      color = "lightgreen")
plt.show()

# %% [markdown]
# Draw a boxplot for the size in cm of the birds.

# %%
box_Size = sns.boxplot(data = birds,
                       x = "Size",
                       color = "lightblue")
plt.show()

# %% [markdown]
# Draw a boxplot for the speed of the birds in km per hour.

# %%
box_Speed = sns.boxplot(data = birds,
                        x = "Speed",
                        color = "orange")
plt.show()

# %% [markdown]
# Draw a boxplot for the weight in kg of the birds.

# %%
box_Weight = sns.boxplot(data = birds,
                         x = "Weight",
                         color = "pink")
plt.show()

# %% [markdown]
# Apply log transformations to the size and to the weight of the birds

# %%
birds["logSize"] = np.log(birds["Size"])
birds["logWeight"] = np.log(birds["Weight"])
# Out:
# /tmp/ipython-input-317273271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birds["logSize"] = np.log(birds["Size"])
# /tmp/ipython-input-317273271.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birds["logWeight"] = np.log(birds["Weight"])

# %%
birds
# Out:
#     Number                      Animal          Habitat Species   Age  \
# 0        1        White headed vulture          Savanna    Bird  20.0
# 1        2               Secretarybird          Savanna    Bird  12.0
# 9       10       Lilac breasted roller          Savanna    Bird  15.0
# 13      14              African jacana          Wetland    Bird   6.5
# 14      15            Greater flamingo          Wetland    Bird  30.0
# 15      16                  Blue crane          Wetland    Bird  30.0
# 17      18            Giant kingfisher          Wetland    Bird  10.0
# 19      20          Southern bald ibis          Wetland    Bird  15.0
# 20      21          African fish eagle          Wetland    Bird  24.0
# 22      23     Brown hooded kingfisher          Wetland    Bird  20.0
# 23      24          Yellow-billed duck          Wetland    Bird  30.0
# 24      25              Crested barbet          Thicket    Bird  10.0
# ...

# %% [markdown]
# Draw a boxplot for the log-transformed size of the birds.

# %%
box_logSize = sns.boxplot(data = birds,
                          x = "logSize",
                          color = "lightblue")
plt.show()

# %% [markdown]
# Draw a boxplot for the log-transformed weight of the birds.

# %%
box_logWeight = sns.boxplot(data = birds,
                            x = "logWeight",
                            color = "pink")
plt.show()

# %% [markdown]
# Draw a histogram for the size in cm of the birds.

# %%
finish = sns.histplot(data = birds,
                      x = "Size",
                      color = "lightblue",
                      edgecolor = "blue",
                      bins = 8)
finish.set(xlabel = "Size in cm",
           ylabel = "Frequency",
           title = "Histogram of the size in cm of the birds")
plt.show()

# %% [markdown]
# Draw a histogram for the weight in kg of the birds.

# %%
finish = sns.histplot(data = birds,
                      x = "Weight",
                      color = "pink",
                      edgecolor = "purple",
                      bins = 8)
finish.set(xlabel = "Weight in kg",
           ylabel = "Frequency",
           title = "Histogram of the weight in kg of the birds")
plt.show()

# %% [markdown]
# Draw a histogram for the log-transformed size of the birds.

# %%
finish = sns.histplot(data = birds,
                      x = "logSize",
                      color = "lightblue",
                      edgecolor = "blue",
                      bins = 8)
finish.set(xlabel = "log(Size) where size is in cm",
           ylabel = "Frequency",
           title = "Histogram of the log-transformed size of the birds")
plt.show()

# %% [markdown]
# Draw a histogram for the log-transformed weight of the birds.

# %%
finish = sns.histplot(data = birds,
                      x = "logWeight",
                      color = "pink",
                      edgecolor = "purple",
                      bins = 8)
finish.set(xlabel = "log(Weight) where weight is in kg",
           ylabel = "Frequency",
           title = "Histogram of the log-transformed weight of the birds")
plt.show()

# %% [markdown]
# Draw a scatterplot of the weight of the birds against the size of the birds

# %%
scatt = sns.scatterplot(data = birds,
                        x = "Size",
                        y = "Weight",
                        color = "red")
scatt.set(xlabel = "Size in cm",
          ylabel = "Weight in kg")
plt.show()

# %% [markdown]
# Draw a scatterplot of the log-transformed weight of the birds against the log-transformed size of the birds.

# %%
scatt = sns.scatterplot(data = birds,
                        x = "logSize",
                        y = "logWeight",
                        color = "red")
scatt.set(xlabel = "log(Size) where size is in cm",
          ylabel = "log(Weight) where weight is in kg")
plt.show()

# %% [markdown]
# ## Exercise: Arachnophobia
#
# In a study on arachnophobia (the fear of spiders), 24 arachnophobes (persons fearing spiders) had to interact with spiders of different sizes. During each interaction, the level of anxiety of the arachnophobe was measured through galvanic skin response (GSR).
#
# Consider the following two variables for $i=1,2,...,24$:
#
# $y_{i}:$ The GSR measurement for the level of anxiety of the $i^{\text{th}}$ arachnophobe.
#
# $x_{i}:$ The size of the spider in centimeters (cm) for the $i^{\text{th}}$ arachnophobe.
#
# Draw boxplots for $y$ and for $x$ and also draw a scatterplot for $y$ against $x$.

# %%
arachno = pd.read_csv("Spiders.csv")
arachno
# Out:
#     GSR  Size
# 0    15   3.0
# 1    20   4.3
# 2    30   9.2
# 3    25   7.6
# 4    35  13.0
# 5    18   6.4
# 6    40   9.9
# 7    10   3.3
# 8    11   5.6
# 9    28  12.0
# 10   26  10.4
# 11   36  13.9
# 12   27   5.9
# 13   17   4.7
# 14   34   9.5
# 15   41  11.3
# 16   50  15.0
# 17   43  11.9
# 18   37  10.7
# 19   21   6.5
# 20   14   5.3
# 21   38  11.6
# 22   45  14.8
# 23   24   8.9

# %%
box_GSR = sns.boxplot(data = arachno,
                        x = "GSR",
                        color = "yellow")
plt.show()

# %%
box_SpiderSize = sns.boxplot(data = arachno,
                             x = "Size",
                             color = "cyan")
plt.show()

# %%
scatt = sns.scatterplot(data = arachno,
                        x = "Size",
                        y = "GSR",
                        color = "magenta")
scatt.set(xlabel = "Size in cm",
          ylabel = "GSR measurement")
plt.show()
